# %%
# %pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.signal import medfilt
import pyqtgraph as pq
import astropy.io.fits as pf

# %%
run /Users/aaronresnick/Desktop/CODERepository/pteropractice/winview_v02.py

# %%
run /Users/aaronresnick/Desktop/CODERepository/pteropractice/chzphot_v02.py

# %%
d = load_spe('Darks5Hzfor60s.SPE')
# Out:
# xs, ys, numFrames, pixType =  256 256 300 uint16

# %%
d = d[1:,:,:]

# %%
darkFiveHz = robostack(d,5,2)

# %%
imshow(darkFiveHz,interpolation='nearest')

# %%
figure(2)

# %%
plot(darkFiveHz[150,:])

# %%
darkFiveHz.dtype
# Out:
# dtype('float64')

# %%
d[128,128,150]
# Out:
# 1095

# %%
dkm = mean(d,axis = 0)

# %%
dkm.shape
# Out:
# (256, 256)

# %%
dkm[128,128]
# Out:
# 1090.8657718120805

# %%
clf()

# %%
imshow(dkm)

# %%
figure(2)

# %%
clf()
plot(dkm[:,128])

# %%
npts = 256

# %%
y,x = indices((npts,npts))

# %%
x1d = ravel(x)

# %%
y1d = ravel(y)

# %%
save(/Users/aaronresnick/Desktop/CODERepository)

# %%
dsum = sum(d,axis=0)

# %%
imshow(dsum)

# %%
# Out:
# 326023
